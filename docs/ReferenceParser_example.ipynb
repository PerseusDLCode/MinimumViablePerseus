# %%
from pathlib import Path
from mvp.corpus import ReferenceParser, LenientTEIDocument
from lxml import etree

# %% [markdown]
# The ReferenceParser operates on a LenientTEIDocument object (an abstraction over TEI XML). Here we create a ReferenceParser for Thucydides.

# %%
tei_filepath = Path("/Users/wulfmanc/mvp/tests/data/structure-data/tlg0003.tlg001.perseus-grc2.xml")
tei_doc = LenientTEIDocument(tei_filepath)
thucydides = ReferenceParser(tei_doc)

# %% [markdown]
# The parser has several methods. The first retrieves the XML object pointed to by a CTS URN.

# %%
urn_base = refparser.base_urn

# %%
etree.tostring(refparser.resolve(f"{urn_base}:1.1"), encoding='unicode', pretty_print=True)
# Out:
# '<div xmlns="http://www.tei-c.org/ns/1.0" type="chapter" n="1">\n               <div type="section" n="1">\n                  <p rend="align(indent)">Θουκυδίδης Ἀθηναῖος ξυνέγραψε τὸν πόλεμον τῶν\n              Πελοποννησίων καὶ Ἀθηναίων, ὡς ἐπολέμησαν πρὸς ἀλλήλους, ἀρξάμενος εὐθὺς καθισταμένου\n              καὶ ἐλπίσας μέγαν τε ἔσεσθαι καὶ ἀξιολογώτατον τῶν προγεγενημένων, τεκμαιρόμενος ὅτι\n              ἀκμάζοντές τε ᾖσαν ἐς αὐτὸν ἀμφότεροι παρασκευῇ τῇ πάσῃ καὶ τὸ ἄλλο Ἑλληνικὸν ὁρῶν\n              ξυνιστάμενον πρὸς ἑκατέρους, τὸ μὲν εὐθύς, τὸ δὲ καὶ διανοούμενον. </p>\n               </div>\n               <div type="section" n="2">\n                  <p>κίνησις γὰρ αὕτη μεγίστη δὴ τοῖς Ἕλλησιν ἐγένετο καὶ μέρει τινὶ τῶν βαρβάρων, ὡς δὲ\n              εἰπεῖν καὶ ἐπὶ πλεῖστον ἀνθρώπων.</p>\n               </div>\n               <div type="section" n="3">\n                  <p>τὰ γὰρ πρὸ αὐτῶν καὶ τὰ ἔτι παλαίτερα σαφῶς μὲν εὑρεῖν διὰ χρόνου πλῆθος ἀδύνατα ἦν,\n              ἐκ 
# ...
